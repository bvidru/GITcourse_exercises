# %%
import pandas as pd

# %%
df_credit = pd.read_csv('tmdb_5000_credits.csv')

# %%
df_credit.sample(5)
# Out:
#       movie_id               title  \
# 3952       342        Summer Storm
# 14       49521        Man of Steel
# 3496     10930  The Flower of Evil
# 561       1997        Two Brothers
# 4314    137955           Crowsnest
#
#                                                    cast  \
# 3952  [{"cast_id": 18, "character": "Tobi", "credit_...
# 14    [{"cast_id": 2, "character": "Clark Kent / Kal...
# 3496  [{"cast_id": 1, "character": "Fran\u00e7ois Va...
# 561   [{"cast_id": 11, "character": "Na\u00ef-Rea", ...
# 4314                                                 []
#
#                                                    crew
# 3952  [{"credit_id": "52fe423ac3a36847f800dd57", "de...
# 14    [{"credit_id": "52fe4799c3a36847f813e667", "de...
# 3496  [{"credit_id": "52fe43d39251416c7501f98d", "de...
# 561   [{"credit_id": "52fe432ac3a36847f803f4c5", "de...
# 4314                                                 []

# %%
df_credit.columns
# Out:
# Index(['movie_id', 'title', 'cast', 'crew'], dtype='object')

# %%
df_credit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4803 entries, 0 to 4802
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   movie_id  4803 non-null   int64
#  1   title     4803 non-null   object
#  2   cast      4803 non-null   object
#  3   crew      4803 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 150.2+ KB

# %%
crew = df_credit['crew']
crew
# Out:
# 0       [{"credit_id": "52fe48009251416c750aca23", "de...
# 1       [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2       [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3       [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# 4       [{"credit_id": "52fe479ac3a36847f813eaa3", "de...
#                               ...
# 4798    [{"credit_id": "52fe44eec3a36847f80b280b", "de...
# 4799    [{"credit_id": "52fe487dc3a368484e0fb013", "de...
# 4800    [{"credit_id": "52fe4df3c3a36847f8275ecf", "de...
# 4801    [{"credit_id": "52fe4ad9c3a368484e16a36b", "de...
# 4802    [{"credit_id": "58ce021b9251415a390165d9", "de...
# Name: crew, Length: 4803, dtype: object

# %%
cast = df_credit['cast']

# %%
df_movie = pd.read_csv('tmdb_5000_movies.csv')

# %%
df_movie.sample(5)
# Out:
#          budget                                             genres  \
# 385   100000000  [{"id": 16, "name": "Animation"}, {"id": 35, "...
# 31    200000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1496   33000000  [{"id": 12, "name": "Adventure"}, {"id": 35, "...
# 3899    3000000  [{"id": 12, "name": "Adventure"}, {"id": 878, ...
# 2448   15000000  [{"id": 80, "name": "Crime"}, {"id": 18, "name...
#
#                                   homepage     id  \
# 385   http://www.warnerbros.com/happy-feet   9836
# 31              http://marvel.com/ironman3  68721
# 1496                                   NaN  11888
# 3899                                   NaN   1685
# 2448                                   NaN  10673
#
#                                                keywords original_language  \
# 385   [{"id": 270, "name": "ocean"}, {"id": 1357, "n...                en
# 31    [{"id": 949, "name": "terrorist"}, {"id": 5597...                en
# ...

# %%
df_movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4803 entries, 0 to 4802
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   budget                4803 non-null   int64
#  1   genres                4803 non-null   object
#  2   homepage              1712 non-null   object
#  3   id                    4803 non-null   int64
#  4   keywords              4803 non-null   object
#  5   original_language     4803 non-null   object
#  6   original_title        4803 non-null   object
#  7   overview              4800 non-null   object
#  8   popularity            4803 non-null   float64
#  9   production_companies  4803 non-null   object
#  10  production_countries  4803 non-null   object
#  11  release_date          4802 non-null   object
#  12  revenue               4803 non-null   int64
#  13  runtime               4801 non-null   float64
#  14  spoken_languages      4803 non-null   object
# ...

# %%
from pandas_profiling import ProfileReport
import numpy as np

# %%
df_movie_workon = df_movie.join(crew)

# %%
df_movie_workon.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3766 entries, 237000000 to 9000
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   title         3766 non-null   object
#  1   popularity    3766 non-null   float64
#  2   revenue       3766 non-null   int64
#  3   vote_average  3766 non-null   float64
#  4   vote_count    3766 non-null   int64
# dtypes: float64(2), int64(2), object(1)
# memory usage: 176.5+ KB

# %%
df_movie_workon = df_movie_workon.join(cast)

# %%
df_movie_workon.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4803 entries, 0 to 4802
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   budget                4803 non-null   int64
#  1   genres                4803 non-null   object
#  2   homepage              1712 non-null   object
#  3   id                    4803 non-null   int64
#  4   keywords              4803 non-null   object
#  5   original_language     4803 non-null   object
#  6   original_title        4803 non-null   object
#  7   overview              4800 non-null   object
#  8   popularity            4803 non-null   float64
#  9   production_companies  4803 non-null   object
#  10  production_countries  4803 non-null   object
#  11  release_date          4802 non-null   object
#  12  revenue               4803 non-null   int64
#  13  runtime               4801 non-null   float64
#  14  spoken_languages      4803 non-null   object
# ...

# %%
profile = ProfileReport(df_movie_workon)
#profile

# %%
df_movie_workon.sample(20)
# Out:
#          budget                                             genres  \
# 2041   22000000  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 2588   15000000                   [{"id": 53, "name": "Thriller"}]
# 3874    3300000                     [{"id": 35, "name": "Comedy"}]
# 1270   45000000  [{"id": 28, "name": "Action"}, {"id": 878, "na...
# 2927   10500000  [{"id": 18, "name": "Drama"}, {"id": 10749, "n...
# 4411          0                      [{"id": 18, "name": "Drama"}]
# 3848    3500000                     [{"id": 28, "name": "Action"}]
# 3121   10000000                     [{"id": 35, "name": "Comedy"}]
# 4301          0  [{"id": 18, "name": "Drama"}, {"id": 10751, "n...
# 2724   18339750  [{"id": 18, "name": "Drama"}, {"id": 36, "name...
# 2039   22000000                     [{"id": 35, "name": "Comedy"}]
# 2370   18000000                    [{"id": 36, "name": "History"}]
# 164   140000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...

# %%
df_movie.columns
# Out:
# Index(['budget', 'genres', 'homepage', 'id', 'keywords', 'original_language',
#        'original_title', 'overview', 'popularity', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'vote_average',
#        'vote_count'],
#       dtype='object')

# %%
list_of_columns = ['title','budget', 'popularity', 'revenue', 'vote_average', 'vote_count']
list_of_columns
# Out:
# ['title', 'budget', 'popularity', 'revenue', 'vote_average', 'vote_count']

# %%
df_cleaned = df_movie[list_of_columns]
df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4803 entries, 0 to 4802
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   title         4803 non-null   object
#  1   budget        4803 non-null   int64
#  2   popularity    4803 non-null   float64
#  3   revenue       4803 non-null   int64
#  4   vote_average  4803 non-null   float64
#  5   vote_count    4803 non-null   int64
# dtypes: float64(2), int64(3), object(1)
# memory usage: 225.3+ KB

# %%
df_worked = df_cleaned.set_index('budget')
df_worked
# Out:
#                                               title  popularity     revenue  \
# budget
# 237000000                                    Avatar  150.437577  2787965087
# 300000000  Pirates of the Caribbean: At World's End  139.082615   961000000
# 245000000                                   Spectre  107.376788   880674609
# 250000000                     The Dark Knight Rises  112.312950  1084939099
# 260000000                               John Carter   43.926995   284139100
# ...                                             ...         ...         ...
# 220000                                  El Mariachi   14.269792     2040920
# 9000                                      Newlyweds    0.642552           0
# 0                         Signed, Sealed, Delivered    1.444476           0
# 0                                  Shanghai Calling    0.857008           0
# 0                                 My Date with Drew    1.929883           0
#
#            vote_average  vote_count
# budget
# ...

# %%
df_worked.reset_index()
# Out:
#          budget                                     title  popularity  \
# 0     237000000                                    Avatar  150.437577
# 1     300000000  Pirates of the Caribbean: At World's End  139.082615
# 2     245000000                                   Spectre  107.376788
# 3     250000000                     The Dark Knight Rises  112.312950
# 4     260000000                               John Carter   43.926995
# ...         ...                                       ...         ...
# 3761         13                               Tin Can Man    0.332679
# 3762      20000                                      Cure    0.212443
# 3763       7000                                    Primer   23.307949
# 3764     220000                               El Mariachi   14.269792
# 3765       9000                                 Newlyweds    0.642552
#
#          revenue  vote_average  vote_count
# 0     2787965087           7.2       11800
# ...

# %%
df_worked = df_cleaned.set_index('revenue')
df_worked
# Out:
#                                                title     budget  popularity  \
# revenue
# 2787965087                                    Avatar  237000000  150.437577
# 961000000   Pirates of the Caribbean: At World's End  300000000  139.082615
# 880674609                                    Spectre  245000000  107.376788
# 1084939099                     The Dark Knight Rises  250000000  112.312950
# 284139100                                John Carter  260000000   43.926995
# ...                                              ...        ...         ...
# 2040920                                  El Mariachi     220000   14.269792
# 0                                          Newlyweds       9000    0.642552
# 0                          Signed, Sealed, Delivered          0    1.444476
# 0                                   Shanghai Calling          0    0.857008
# 0                                  My Date with Drew          0    1.929883
#
#             vote_average  vote_count
# revenue
# ...

# %%
df_worked = df_worked.reset_index()
df_worked
# Out:
#          revenue                                     title     budget  \
# 0     2787965087                                    Avatar  237000000
# 1      961000000  Pirates of the Caribbean: At World's End  300000000
# 2      880674609                                   Spectre  245000000
# 3     1084939099                     The Dark Knight Rises  250000000
# 4      284139100                               John Carter  260000000
# ...          ...                                       ...        ...
# 3371       76901                               Funny Ha Ha          0
# 3372     6000000                            Pink Flamingos      12000
# 3373       99000                                      Cure      20000
# 3374      424760                                    Primer       7000
# 3375     2040920                               El Mariachi     220000
#
#       popularity  vote_average  vote_count
# 0     150.437577           7.2       11800
# ...

# %%
df_worked.budget.value_counts()
# Out:
# 0           147
# 20000000    126
# 25000000    115
# 30000000    114
# 40000000    111
#            ...
# 92620000      1
# 14600000      1
# 14800000      1
# 14500000      1
# 220000        1
# Name: budget, Length: 386, dtype: int64

# %%
df_worked.revenue.value_counts()
# Out:
# 8000000      6
# 7000000      6
# 6000000      5
# 100000000    5
# 10000000     5
#             ..
# 124827316    1
# 75505856     1
# 124731534    1
# 158733820    1
# 2040920      1
# Name: revenue, Length: 3296, dtype: int64

# %%
df_worked.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3376 entries, 0 to 3375
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   revenue       3376 non-null   int64
#  1   title         3376 non-null   object
#  2   budget        3376 non-null   int64
#  3   popularity    3376 non-null   float64
#  4   vote_average  3376 non-null   float64
#  5   vote_count    3376 non-null   int64
# dtypes: float64(2), int64(3), object(1)
# memory usage: 158.4+ KB

# %%
df_worked[df_worked['budget'] == 0]
# Out:
#         revenue                                   title  budget  popularity  \
# 317   104907746                            The Campaign       0   16.460356
# 355   233755553  Alvin and the Chipmunks: The Road Chip       0   27.867368
# 403    37823676                           All That Jazz       0    5.159407
# 463    43312294                                The Edge       0   20.632673
# 477    19406406                                  Oceans       0   10.706613
# ...         ...                                     ...     ...         ...
# 3327     110197                                Dogtooth       0   28.858238
# 3334     319285                              Compliance       0    8.942203
# 3351    2611555                                   Three       0    5.937602
# 3368     321952                          The Last Waltz       0    3.277287
# 3371      76901                             Funny Ha Ha       0    0.362633
#
#       vote_average  vote_count
# ...

# %%
df_worked = df_worked.set_index('budget')

# %%
df_worked
# Out:
#               revenue                                     title  popularity  \
# budget
# 237000000  2787965087                                    Avatar  150.437577
# 300000000   961000000  Pirates of the Caribbean: At World's End  139.082615
# 245000000   880674609                                   Spectre  107.376788
# 250000000  1084939099                     The Dark Knight Rises  112.312950
# 260000000   284139100                               John Carter   43.926995
# ...               ...                                       ...         ...
# 0               76901                               Funny Ha Ha    0.362633
# 12000         6000000                            Pink Flamingos    4.553644
# 20000           99000                                      Cure    0.212443
# 7000           424760                                    Primer   23.307949
# 220000        2040920                               El Mariachi   14.269792
#
#            vote_average  vote_count
# budget
# ...

# %%
df_worked = df_worked.drop(0, axis =0)

# %%
df_worked = df_worked.reset_index()

# %%
df_worked
# Out:
#          budget     revenue                                     title  \
# 0     237000000  2787965087                                    Avatar
# 1     300000000   961000000  Pirates of the Caribbean: At World's End
# 2     245000000   880674609                                   Spectre
# 3     250000000  1084939099                     The Dark Knight Rises
# 4     260000000   284139100                               John Carter
# ...         ...         ...                                       ...
# 3224      27000     3151130                                    Clerks
# 3225      12000     6000000                            Pink Flamingos
# 3226      20000       99000                                      Cure
# 3227       7000      424760                                    Primer
# 3228     220000     2040920                               El Mariachi
#
#       popularity  vote_average  vote_count
# 0     150.437577           7.2       11800
# ...

# %%
df_worked.describe()
# Out:
#              budget       revenue   popularity  vote_average    vote_count
# count  3.229000e+03  3.229000e+03  3229.000000   3229.000000   3229.000000
# mean   4.065444e+07  1.212430e+08    29.033689      6.309353    977.287395
# std    4.439674e+07  1.863029e+08    36.165730      0.873891   1414.309577
# min    1.000000e+00  5.000000e+00     0.019984      0.000000      0.000000
# 25%    1.050000e+07  1.700000e+07    10.446722      5.800000    178.000000
# 50%    2.500000e+07  5.518472e+07    20.410354      6.300000    471.000000
# 75%    5.500000e+07  1.462920e+08    37.335721      6.900000   1148.000000
# max    3.800000e+08  2.787965e+09   875.581305      8.500000  13752.000000

# %%
df_worked.budget.value_counts()
# Out:
# 20000000    126
# 25000000    115
# 30000000    114
# 40000000    111
# 15000000    107
#            ...
# 92620000      1
# 14600000      1
# 14800000      1
# 14500000      1
# 220000        1
# Name: budget, Length: 385, dtype: int64

# %%
len(df_worked.budget)
# Out:
# 3229

# %%
len(df_worked.revenue)
# Out:
# 3229

# %%
df_worked.sample()
# Out:
#        budget   revenue                 title  popularity  vote_average  \
# 2481  6400000  35057696  My Week with Marilyn   21.006078           6.6
#
#       vote_count
# 2481         406

# %%
X = df_worked.drop(columns = ['revenue', 'title'])
y = df_worked['revenue']

# %%
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
regressor = LinearRegression()

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 2)
regressor.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
regressor.intercept_
# Out:
# -14729209.376111135

# %%
y_pred = regressor.predict(X_test)
#y_pred

# %%
def run_rf_model(depth, df, list_variants):
    import sklearn.metrics as metrics
    model=RandomForestRegressor(random_state =0, n_estimators=1000, max_depth=depth)
    for _ in list_variants[:2]:
    X_train = df[]
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    print(f'R-Squared for depth {depth} is:', metrics.r2_score(y_pred, y_test))

# %%
profile = ProfileReport(df_movie_workon)
#profile

# %%
df_movie_workon = df_movie_workon.drop(0, axis = 0)

# %%
df_movie_workon
# Out:
#                                               title  popularity     revenue  \
# budget
# 237000000                                    Avatar  150.437577  2787965087
# 300000000  Pirates of the Caribbean: At World's End  139.082615   961000000
# 245000000                                   Spectre  107.376788   880674609
# 250000000                     The Dark Knight Rises  112.312950  1084939099
# 260000000                               John Carter   43.926995   284139100
# ...                                             ...         ...         ...
# 13                                      Tin Can Man    0.332679           0
# 20000                                          Cure    0.212443       99000
# 7000                                         Primer   23.307949      424760
# 220000                                  El Mariachi   14.269792     2040920
# 9000                                      Newlyweds    0.642552           0
#
#            vote_average  vote_count
# budget
# ...

# %%
df_movie_workon.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3766 entries, 237000000 to 9000
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   title         3766 non-null   object
#  1   popularity    3766 non-null   float64
#  2   revenue       3766 non-null   int64
#  3   vote_average  3766 non-null   float64
#  4   vote_count    3766 non-null   int64
# dtypes: float64(2), int64(2), object(1)
# memory usage: 176.5+ KB

# %%
df_movie_workon.describe()
# Out:
#         popularity       revenue  vote_average    vote_count
# count  3766.000000  3.766000e+03   3766.000000   3766.000000
# mean     25.984641  1.039547e+08      6.226474    856.496814
# std      34.438253  1.776399e+08      0.966228   1344.785690
# min       0.001586  0.000000e+00      0.000000      0.000000
# 25%       7.974990  6.009736e+06      5.700000    114.000000
# 50%      17.604955  3.883137e+07      6.300000    365.500000
# 75%      33.925801  1.220873e+08      6.900000    969.250000
# max     875.581305  2.787965e+09     10.000000  13752.000000

# %%
df_movie_workon.set_index('title')
# Out:
#                                           popularity     revenue  \
# title
# Avatar                                    150.437577  2787965087
# Pirates of the Caribbean: At World's End  139.082615   961000000
# Spectre                                   107.376788   880674609
# The Dark Knight Rises                     112.312950  1084939099
# John Carter                                43.926995   284139100
# ...                                              ...         ...
# Tin Can Man                                 0.332679           0
# Cure                                        0.212443       99000
# Primer                                     23.307949      424760
# El Mariachi                                14.269792     2040920
# Newlyweds                                   0.642552           0
#
#                                           vote_average  vote_count
# title
# Avatar                                             7.2       11800
# ...

# %%
df_movie_workon.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3766 entries, 237000000 to 9000
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   title         3766 non-null   object
#  1   popularity    3766 non-null   float64
#  2   revenue       3766 non-null   int64
#  3   vote_average  3766 non-null   float64
#  4   vote_count    3766 non-null   int64
# dtypes: float64(2), int64(2), object(1)
# memory usage: 176.5+ KB

# %%
df_movie_workon.popularity.value_counts()
# Out:
# 8.902102      2
# 150.437577    1
# 7.247023      1
# 14.038703     1
# 3.949796      1
#              ..
# 15.011624     1
# 82.052056     1
# 45.083509     1
# 65.364452     1
# 1.929883      1
# Name: popularity, Length: 4802, dtype: int64

# %%
df_movie_workon.revenue.value_counts()
# Out:
# 0            1427
# 7000000         6
# 8000000         6
# 6000000         5
# 12000000        5
#              ...
# 124827316       1
# 75505856        1
# 124731534       1
# 158733820       1
# 2040920         1
# Name: revenue, Length: 3297, dtype: int64

# %%
import pandas as pd

# %%
df_kaggle = pd.read_csv('kaggle_survey_2022_responses.csv', low_memory = False)
df_kaggle.head()
# Out:
#    Duration (in seconds)                           Q2  \
# 0  Duration (in seconds)  What is your age (# years)?
# 1                    121                        30-34
# 2                    462                        30-34
# 3                    293                        18-21
# 4                    851                        55-59
#
#                                        Q3  \
# 0  What is your gender? - Selected Choice
# 1                                     Man
# 2                                     Man
# 3                                     Man
# 4                                     Man
#
#                                           Q4  \
# 0  In which country do you currently reside?
# 1                                      India
# 2                                    Algeria
# 3                                      Egypt
# 4                                     France
#
#                                                   Q5  \
# ...

# %%
df_kaggle.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23998 entries, 0 to 23997
# Columns: 296 entries, Duration (in seconds) to Q44_12
# dtypes: object(296)
# memory usage: 54.2+ MB

# %%
df_kaggle.columns
# Out:
# Index(['Duration (in seconds)', 'Q2', 'Q3', 'Q4', 'Q5', 'Q6_1', 'Q6_2', 'Q6_3',
#        'Q6_4', 'Q6_5',
#        ...
#        'Q44_3', 'Q44_4', 'Q44_5', 'Q44_6', 'Q44_7', 'Q44_8', 'Q44_9', 'Q44_10',
#        'Q44_11', 'Q44_12'],
#       dtype='object', length=296)

# %%
df_medical = pd.read_csv('insurance.csv')
df_medical.head(3)
# Out:
#    age     sex    bmi  children smoker     region     charges
# 0   19  female  27.90         0    yes  southwest  16884.9240
# 1   18    male  33.77         1     no  southeast   1725.5523
# 2   28    male  33.00         3     no  southeast   4449.4620

# %%
import numpy as np 
import pandas as pd 
import os
import matplotlib.pyplot as pl
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df_medical.isnull()
# Out:
#         age    sex    bmi  children  smoker  region  charges
# 0     False  False  False     False   False   False    False
# 1     False  False  False     False   False   False    False
# 2     False  False  False     False   False   False    False
# 3     False  False  False     False   False   False    False
# 4     False  False  False     False   False   False    False
# ...     ...    ...    ...       ...     ...     ...      ...
# 1333  False  False  False     False   False   False    False
# 1334  False  False  False     False   False   False    False
# 1335  False  False  False     False   False   False    False
# 1336  False  False  False     False   False   False    False
# 1337  False  False  False     False   False   False    False
#
# [1338 rows x 7 columns]

# %%
df_medical.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
#sex
le = LabelEncoder()
le.fit(df_medical.sex.drop_duplicates()) 
df_medical.sex = le.transform(df_medical.sex)
# smoker or not
le.fit(df_medical.smoker.drop_duplicates()) 
df_medical.smoker = le.transform(df_medical.smoker)
#region
le.fit(df_medical.region.drop_duplicates()) 
df_medical.region = le.transform(df_medical.region)

# %%
df_medical.region.value_counts()
# Out:
# 2    364
# 3    325
# 1    325
# 0    324
# Name: region, dtype: int64

# %%
df_medical.sex.drop_duplicates()
# Out:
# 0    0
# 1    1
# Name: sex, dtype: int32

# %%
df_medical
# Out:
#       age  sex     bmi  children  smoker  region      charges
# 0      19    0  27.900         0       1       3  16884.92400
# 1      18    1  33.770         1       0       2   1725.55230
# 2      28    1  33.000         3       0       2   4449.46200
# 3      33    1  22.705         0       0       1  21984.47061
# 4      32    1  28.880         0       0       1   3866.85520
# ...   ...  ...     ...       ...     ...     ...          ...
# 1333   50    1  30.970         3       0       1  10600.54830
# 1334   18    0  31.920         0       0       0   2205.98080
# 1335   18    0  36.850         0       0       2   1629.83350
# 1336   21    0  25.800         0       0       3   2007.94500
# 1337   61    0  29.070         0       1       1  29141.36030
#
# [1338 rows x 7 columns]

# %%
df_medical.corr()
# Out:
#                age       sex       bmi  children    smoker    region   charges
# age       1.000000 -0.020856  0.109272  0.042469 -0.025019  0.002127  0.299008
# sex      -0.020856  1.000000  0.046371  0.017163  0.076185  0.004588  0.057292
# bmi       0.109272  0.046371  1.000000  0.012759  0.003750  0.157566  0.198341
# children  0.042469  0.017163  0.012759  1.000000  0.007673  0.016569  0.067998
# smoker   -0.025019  0.076185  0.003750  0.007673  1.000000 -0.002181  0.787251
# region    0.002127  0.004588  0.157566  0.016569 -0.002181  1.000000 -0.006208
# charges   0.299008  0.057292  0.198341  0.067998  0.787251 -0.006208  1.000000

# %%
df_medical.corr()['charges']
# Out:
# age         0.299008
# sex         0.057292
# bmi         0.198341
# children    0.067998
# smoker      0.787251
# region     -0.006208
# charges     1.000000
# Name: charges, dtype: float64

# %%
df_medical.corr()['charges'].sort_values()
# Out:
# region     -0.006208
# sex         0.057292
# children    0.067998
# bmi         0.198341
# age         0.299008
# smoker      0.787251
# charges     1.000000
# Name: charges, dtype: float64

# %%
f, ax = pl.subplots(figsize=(6, 4))
corr = df_medical.corr()
sns.heatmap(corr, mask=np.zeros_like(corr, dtype=np.bool), cmap=sns.diverging_palette(240,10,as_cmap=True),
            square=True, ax=ax)
# Out:
# <AxesSubplot:>

# %%
lista_orase = ['paris', 'paris', 'tokyo', 'amsterdam']

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
le.fit(lista_orase)
# Out:
# LabelEncoder()

# %%
list(le.classes_)
# Out:
# ['amsterdam', 'paris', 'tokyo']

# %%
le.transform(['tokyo', 'tokyo', 'paris'])
# Out:
# array([2, 2, 1])

# %%
le.transform(['paris', 'amsterdam', 'paris'])
# Out:
# array([1, 0, 1])

# %%
def display_gif(fn):
    from IPython import display
    return display.HTML('<img src="{}">'.format(fn))

# %%
from bokeh.io import output_notebook, show
from bokeh.plotting import figure
output_notebook()
import scipy.special
from bokeh.layouts import gridplot
from bokeh.plotting import figure, show, output_file
p = figure(title="Distribution of charges",tools="save",
            background_fill_color="#E8DDCB")
hist, edges = np.histogram(data.charges)
p.quad(top=hist, bottom=0, left=edges[:-1], right=edges[1:],
        fill_color="#036564", line_color="#033649")
p.xaxis.axis_label = 'x'
p.yaxis.axis_label = 'Pr(x)'
show(gridplot(p,ncols = 2, plot_width=400, plot_height=400, toolbar_location=None))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [140], in <cell line: 1>()
# ----> 1 from bokeh.io import output_notebook, show
#       2 from bokeh.plotting import figure
#       3 output_notebook()
#
# ModuleNotFoundError: No module named 'bokeh'

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split, cross_val_score, cross_val_predict
import operator

# %%
df_weather = pd.read_csv('weatherHistory.csv')

# %%
df_weather.sample(3)
# Out:
#                       Formatted Date        Summary Precip Type  \
# 64214  2013-02-07 14:00:00.000 +0100  Mostly Cloudy        rain
# 70844  2014-04-08 20:00:00.000 +0200  Mostly Cloudy        rain
# 39748  2010-06-20 04:00:00.000 +0200  Mostly Cloudy        rain
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 64214         2.838889                 -1.733333      0.76            20.7368
# 70844        16.355556                 16.355556      0.57             7.8729
# 39748        15.444444                 15.444444      1.00             3.0268
#
#        Wind Bearing (degrees)  Visibility (km)  Loud Cover  \
# 64214                   270.0          11.2700         0.0
# 70844                   144.0          15.1823         0.0
# 39748                   138.0           6.1985         0.0
#
#        Pressure (millibars)                      Daily Summary
# 64214               1003.47  Mostly cloudy throughout the day.
# ...

# %%
df_weather.describe().T
# Out:
#                             count         mean         std        min  \
# Temperature (C)           96453.0    11.932678    9.551546 -21.822222
# Apparent Temperature (C)  96453.0    10.855029   10.696847 -27.716667
# Humidity                  96453.0     0.734899    0.195473   0.000000
# Wind Speed (km/h)         96453.0    10.810640    6.913571   0.000000
# Wind Bearing (degrees)    96453.0   187.509232  107.383428   0.000000
# Visibility (km)           96453.0    10.347325    4.192123   0.000000
# Loud Cover                96453.0     0.000000    0.000000   0.000000
# Pressure (millibars)      96453.0  1003.235956  116.969906   0.000000
#
#                                   25%        50%          75%          max
# Temperature (C)              4.688889    12.0000    18.838889    39.905556
# Apparent Temperature (C)     2.311111    12.0000    18.838889    39.344444
# Humidity                     0.600000     0.7800     0.890000     1.000000
# ...

# %%
df_weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96453 entries, 0 to 96452
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Formatted Date            96453 non-null  object
#  1   Summary                   96453 non-null  object
#  2   Precip Type               95936 non-null  object
#  3   Temperature (C)           96453 non-null  float64
#  4   Apparent Temperature (C)  96453 non-null  float64
#  5   Humidity                  96453 non-null  float64
#  6   Wind Speed (km/h)         96453 non-null  float64
#  7   Wind Bearing (degrees)    96453 non-null  float64
#  8   Visibility (km)           96453 non-null  float64
#  9   Loud Cover                96453 non-null  float64
#  10  Pressure (millibars)      96453 non-null  float64
#  11  Daily Summary             96453 non-null  object
# dtypes: float64(8), object(4)
# memory usage: 8.8+ MB

# %%
df_weather.describe()
# Out:
#        Temperature (C)  Apparent Temperature (C)      Humidity  \
# count     96453.000000              96453.000000  96453.000000
# mean         11.932678                 10.855029      0.734899
# std           9.551546                 10.696847      0.195473
# min         -21.822222                -27.716667      0.000000
# 25%           4.688889                  2.311111      0.600000
# 50%          12.000000                 12.000000      0.780000
# 75%          18.838889                 18.838889      0.890000
# max          39.905556                 39.344444      1.000000
#
#        Wind Speed (km/h)  Wind Bearing (degrees)  Visibility (km)  Loud Cover  \
# count       96453.000000            96453.000000     96453.000000     96453.0
# mean           10.810640              187.509232        10.347325         0.0
# std             6.913571              107.383428         4.192123         0.0
# min             0.000000                0.000000         0.000000         0.0
# ...

# %%
df_weather1= df_weather[['Temperature (C)','Apparent Temperature (C)', 'Humidity']]

# %%
df_weather1.columns = ['Temperature', 'Apparent_Temperature', 'Humidity']

# %%
df_weather
# Out:
#                       Formatted Date        Summary Precip Type  \
# 0      2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain
# 1      2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain
# 2      2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain
# 3      2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain
# 4      2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain
# ...                              ...            ...         ...
# 96448  2016-09-09 19:00:00.000 +0200  Partly Cloudy        rain
# 96449  2016-09-09 20:00:00.000 +0200  Partly Cloudy        rain
# 96450  2016-09-09 21:00:00.000 +0200  Partly Cloudy        rain
# 96451  2016-09-09 22:00:00.000 +0200  Partly Cloudy        rain
# 96452  2016-09-09 23:00:00.000 +0200  Partly Cloudy        rain
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0             9.472222                  7.388889      0.89            14.1197
# ...

# %%
df_weather = df_weather[:][:500]
df_weather.head(2)
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                   251.0          15.8263         0.0               1015.13
# 1                   259.0          15.8263         0.0               1015.63
#
#                        Daily Summary
# 0  Partly cloudy throughout the day.
# 1  Partly cloudy throughout the day.

# %%
sns.pairplot(df_weather, kind="reg")

# %%
y = np.array(df_weather1['Humidity'])[:500].reshape(-1, 1)
X = np.array(df_weather1['Apparent_Temperature'])[:500].reshape(-1, 1)
X.shape, y.shape
# Out:
# ((500, 1), (500, 1))

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 42)

# %%
from sklearn.linear_model import LinearRegression

lin_df = LinearRegression()  
lin_df.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = lin_df.predict(X_test)                                     # Predict Linear Model
accuracy_score = lin_df.score(X_test, y_test)                       # Accuracy score
print("Linear Regression Model Accuracy Score: " + "{:.1%}".format(accuracy_score))
# Out:
# Linear Regression Model Accuracy Score: 54.4%

# %%
from sklearn.metrics import mean_squared_error,r2_score

print("R2 Score: " +"{:.3}".format(r2_score(y_test, y_pred)));
# Out:
# R2 Score: 0.544

# %%
# Finally draw figure of Linear Regression Model

plt.scatter(X_test, y_test, color='r')
plt.plot(X_test, y_pred, color='g')
plt.show()

# %%
X = df_weather.drop(columns = ['Humidity', '']
y = df_weather[['Humidity']]
# Out:
#   Input In [25]
#     X = df_weather.drop(columns = ['Humidity', '']
#                        ^
# SyntaxError: '(' was never closed

# %%
X1 = df_weather.drop(columns=['Humidity', 'Formatted Date', 'Summary', 'Precip Type', 'Daily Summary'])[:500]
y1 = df_weather[['Humidity']][:500]
X1.shape, y1.shape
X1_train, X1_test, y1_train, y1_test = train_test_split(X1, y1, test_size = 0.20, random_state = 42)
# Out:
# ((500, 7), (500, 1))

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 42)
mlin_df = LinearRegression()
mlin_df = mlin_df.fit(X_train, y_train)
mlin_df.intercept_       # constant b0
mlin_df.coef_
# Out:
# array([[-0.02416254]])

# %%
y_pred = mlin_df.predict(X_train)                                      # predict Multi linear Reg model
rmse = np.sqrt(mean_squared_error(y_train, mlin_df.predict(X_train)))
print("RMSE Score for Test set: " +"{:.2}".format(rmse))
print("R2 Score for Test set: " +"{:.3}".format(r2_score(y_train, y_pred)));      # this is test error score
# Out:
# RMSE Score for Test set: 0.11
# R2 Score for Test set: 0.539

# %%
# cross validation method is giving better and clear result

cross_val_score(mlin_df, X, y, cv=10, scoring = 'r2').mean()
# Out:
# -0.01302036651067957

# %%
mlin_df.score(X_train, y_train)      # r2 value
# Out:
# 0.5386375277111362

# %%
np.sqrt(-cross_val_score(mlin_df, 
                X_train, 
                y_train, 
                cv=10, 
                scoring = 'neg_mean_squared_error')).mean()
# Out:
# 0.11291532622319658

# %%
y1 = np.array(df_weather['Humidity'])[:500].reshape(-1, 1)
X1 = np.array(df_weather['Apparent_Temperature'])[:500].reshape(-1, 1)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 42)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\Envs\curs_python\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\Envs\curs_python\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\Envs\curs_python\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Apparent_Temperature'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
# Finally draw figure of Multiple Linear Regression Model

plt.scatter(X1_train, y1_train, s=100)

# sort the values of x before line plot
sort_axis = operator.itemgetter(0)
sorted_zip = sorted(zip(X_train,y_pred), key=sort_axis)
X_test, y_pred = zip(*sorted_zip)
plt.plot(X_train, y_train, color='r')
plt.show(
# Out:
#   Input In [67]
#     plt.show(
#              ^
# SyntaxError: incomplete input

# %%
from sklearn.preprocessing import PolynomialFeatures

poly_df = PolynomialFeatures(degree = 5)
transform_poly = poly_df.fit_transform(X_train)

linreg2 = LinearRegression()
linreg2.fit(transform_poly,y_train)

polynomial_predict = linreg2.predict(transform_poly)

# %%
rmse = np.sqrt(mean_squared_error(y_train,polynomial_predict))
r2 = r2_score(y_train,polynomial_predict)
print("RMSE Score for Test set: " +"{:.2}".format(rmse))
print("R2 Score for Test set: " +"{:.2}".format(r2))
# Out:
# RMSE Score for Test set: 0.095
# R2 Score for Test set: 0.67

# %%
plt.scatter(X_train, y_train, s=50)
# sort the values of x before line plot
sort_axis = operator.itemgetter(0)
sorted_zip = sorted(zip(X_train,polynomial_predict), key=sort_axis)
X_train, polynomial_predict = zip(*sorted_zip)
plt.plot(X_train, polynomial_predict, color='m')
plt.show()

# %%
from sklearn.tree import DecisionTreeRegressor

dt_reg = DecisionTreeRegressor()          # create  DecisionTreeReg with sklearn
dt_reg.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
dt_predict = dt_reg.predict(X_train)
#dt_predict.mean()

# %%
plt.scatter(X_train,y_train, color="red")                           # scatter draw
X_grid = np.arange(min(np.array(X_train)),max(np.array(X_train)), 0.01)  
X_grid = X_grid.reshape((len(X_grid), 1))
plt.plot(X_grid,dt_reg.predict(X_grid),color="g")                 # line draw
plt.xlabel("Temperature")
plt.ylabel("Humidity")
plt.title("Decision Tree Model")
plt.show()

# %%
X1 = df_weather.drop(columns=['Humidity', 'Formatted Date', 'Summary', 'Precip Type', 'Daily Summary'])[:500]
y1 = df_weather[['Humidity']][:500]
X1.shape, y1.shape
X1_train, X1_test, y1_train, y1_test = train_test_split(X1, y1, test_size = 0.20, random_state = 42)

# %%
X1.columns
# Out:
# Index(['Temperature (C)', 'Apparent Temperature (C)', 'Wind Speed (km/h)',
#        'Wind Bearing (degrees)', 'Visibility (km)', 'Loud Cover',
#        'Pressure (millibars)'],
#       dtype='object')

# %%
y1.dtype
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 y1.dtype
#
# NameError: name 'y1' is not defined

# %%
from dtreeviz.trees import dtreeviz
from sklearn import tree
viz = dtreeviz(dt_reg,
               X1_train,
               y1_train,
               target_name = 'Humidity',
               feature_names = X1.columns,
               title = 'Bla bla',
               fontname = 'Arial',
               title_fontsize = 16,
               colors = {'tile':'purple'}
              )
viz
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [99], in <cell line: 3>()
#       1 from dtreeviz.trees import dtreeviz
#       2 from sklearn import tree
# ----> 3 viz = dtreeviz(dt_reg,
#       4                X1_train,
#       5                y1_train,
#       6                target_name = 'Humidity',
#       7                feature_names = X1.columns,
#       8                title = 'Bla bla',
#       9                fontname = 'Arial',
#      10                title_fontsize = 16,
#      11                colors = {'tile':'purple'}
#      12               )
#      13 viz
#
# ...

# %%
from sklearn import tree
text_representation = tree.export_text(dt_reg)
print(text_representation)
# Out:
# |--- feature_0 <= 17.74
# |   |--- feature_0 <= 13.16
# |   |   |--- feature_0 <= 13.02
# |   |   |   |--- feature_0 <= 12.79
# |   |   |   |   |--- feature_0 <= 11.98
# |   |   |   |   |   |--- feature_0 <= 11.49
# |   |   |   |   |   |   |--- feature_0 <= 11.03
# |   |   |   |   |   |   |   |--- feature_0 <= 10.69
# |   |   |   |   |   |   |   |   |--- feature_0 <= 10.14
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 9.44
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 9.37
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 18
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  9.37
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  9.44
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 10.08
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  10.08
# ...
